# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
mainpath = "datasets"
filename = "covid.csv"
fullpath = os.path.join(mainpath, filename)

# %%
data = pd.read_csv(fullpath, sep=';')

# %%
data.head(10)
# Out:
#    FECHA_CORTE                              UUID DEPARTAMENTO  \
# 0     20201209  7320cabdc1aaca6c59014cae76a134e6  LIMA REGION
# 1     20201209  e81602051997ace8340bb8c18fe24c65         LIMA
# 2     20201209  cecdbf10074dbc011ae05b3cbd320a6f         LIMA
# 3     20201209  71ecb6bccb248b0bb2ac72ed51b5e979         LIMA
# 4     20201209  566af4276cbe9359abe93f9aa86396c3       CALLAO
# 5     20201209  027561e9d126e7c283d79c02cede562d   LAMBAYEQUE
# 6     20201209  f016889b9ba5bd95cf15d60205cbd82e         LIMA
# 7     20201209  971f8e1295583756d81fe42f3318488c       CALLAO
# 8     20201209  bc45b71b005a96f32eeb97060616a999     AREQUIPA
# 9     20201209  0e2a1928ddd07d99978758e86b034131         LIMA
#
#           PROVINCIA                DISTRITO METODODX  EDAD       SEXO  \
# 0  EN INVESTIGACIÓN        EN INVESTIGACIÓN      PCR  41.0  MASCULINO
# 1              LIMA                   BREÑA      PCR  41.0  MASCULINO
# 2              LIMA                    LIMA      PCR  51.0  MASCULINO
# ...

# %%
grouped_gender = data.groupby("PROVINCIA")

# %%
for names, groups in grouped_gender:
    print(names)
    print("=============================")
    print(groups)
# Out:
# ABANCAY
# ...
#         FECHA_CORTE                              UUID DEPARTAMENTO PROVINCIA  \
# 577        20201209  4f7901a07466b6c96f7ca93c3ab07d7b     APURIMAC   ABANCAY
# 1295       20201209  9ae889a5e5717da3001f326ea625b006     APURIMAC   ABANCAY
# 1367       20201209  6796abee2b9041e1d59697fd05abbcfe     APURIMAC   ABANCAY
# 1417       20201209  5e0a2118a63575553060115e529c9b44     APURIMAC   ABANCAY
# 2110       20201209  c5d484c545f691ab5e3c7bb2c99d5528     APURIMAC   ABANCAY
# ...             ...                               ...          ...       ...
# 978518     20201209  33f1c73875bb79f585b8e3c5244d4652     APURIMAC   ABANCAY
# 978564     20201209  64c60b21f25c0ce5aa979e4a8a24255f     APURIMAC   ABANCAY
# 978693     20201209  564c9044c8ccd7015522621e52745358     APURIMAC   ABANCAY
# 978694     20201209  102aa180d7db07ab1fe95da226abe3bf     APURIMAC   ABANCAY
# 979094     20201209  bdb6407a112a81b35ff62f3d1cb76d00     APURIMAC   ABANCAY
#
# ...

# %%
grouped_gender.get_group("TACNA")
# Out:
#         FECHA_CORTE                              UUID DEPARTAMENTO PROVINCIA  \
# 341        20201209  db575efcfefa81cae5004e6f28be8ed1        TACNA     TACNA
# 396        20201209  0226cc3ff9a088983805374d0318f2f7        TACNA     TACNA
# 507        20201209  4475ec3d7bcab93620799ed7dbf22196        TACNA     TACNA
# 24226      20201209  21d5a7bd4278bb8a61577df80eba669c        TACNA     TACNA
# 24271      20201209  b24dd37142cd281d41b0e56e02718872        TACNA     TACNA
# ...             ...                               ...          ...       ...
# 978935     20201209  831e032dcb63a57e29f4b8fa99b80804        TACNA     TACNA
# 979021     20201209  fef7e7b185c49c1fa0082cfb5fd8d226        TACNA     TACNA
# 979027     20201209  251040a7130386ffc104d9a807b576b9        TACNA     TACNA
# 979086     20201209  b7bb6f0f7ffc155e593f52d6dd71cbab        TACNA     TACNA
# 979088     20201209  da997b4b5f9b5074cab93697848ed037        TACNA     TACNA
#
# ...

# %%
double_group = data.groupby(["SEXO", "EDAD"])

# %%
len(double_group)
# Out:
# 264

# %%
for names, groups in double_group:
    print(names)
    print(groups)
# Out:
# ('FEMENINO', 0.0)
#         FECHA_CORTE                              UUID DEPARTAMENTO PROVINCIA  \
# 24410      20201209  fa0905d5bc9062ee68408e305d377753        JUNIN  HUANCAYO
# 26422      20201209  ef1452843c311b42a26cde06accdb2fd         LIMA      LIMA
# 26546      20201209  69c7130e7ac9a5537f6296d144d7d28e    CAJAMARCA      JAEN
# 37170      20201209  0356c9759644cbad8d27746035ddd54f  LA LIBERTAD  TRUJILLO
# 38156      20201209  88daccb31ee7fe7945dec0ef26645b1f  LA LIBERTAD  TRUJILLO
# ...             ...                               ...          ...       ...
# 977111     20201209  30bf30f7252070b654473657e0eaba76        JUNIN  HUANCAYO
# 977519     20201209  0b4af69ddaf4689cbd6d5f87d2973f49     AYACUCHO  HUAMANGA
# 977727     20201209  70f54b2fd142d865b138c73a93333751       ANCASH     SANTA
# 978086     20201209  fc55fc76c231eacb75c6b0a1c4f097da         LIMA      LIMA
# 978834     20201209  995d8b4580cddd52b060302edf91826b         LIMA      LIMA
#
# ...

# %%
data.tail(8)
# Out:
#         FECHA_CORTE                              UUID DEPARTAMENTO PROVINCIA  \
# 979103     20201209  b219c88754adec561aa01ce9eea1e4eb         LIMA      LIMA
# 979104     20201209  0a6016b4361f2ff41c8105e2884ec98f       CALLAO    CALLAO
# 979105     20201209  43e10f9807bbfbe77e27021734c98216  LA LIBERTAD  TRUJILLO
# 979106     20201209  83e463e6ba1475b3adf47a14aec4c1a9       CALLAO    CALLAO
# 979107     20201209  24b1a51a3f56a21a612fa046018f4081        CUSCO  URUBAMBA
# 979108     20201209  ab441734c7186c686d3960876cd955c8        JUNIN  HUANCAYO
# 979109     20201209  7c2b520da2366ba0de03d6d63dc4b823  LIMA REGION  BARRANCA
# 979110     20201209  5f083ae950570d0bd36b6bdd1ea0e7c2         LIMA      LIMA
#
#                  DISTRITO METODODX  EDAD       SEXO  FECHA_RESULTADO
# 979103        SANTA ANITA       PR  33.0   FEMENINO       20201129.0
# 979104             CALLAO       PR  22.0   FEMENINO       20201128.0
# 979105       LA ESPERANZA       PR  23.0  MASCULINO       20201125.0
# ...

# %%
double_group["EDAD"].filter(lambda x: x.sum()>40)
# Out:
# 0         41.0
# 1         41.0
# 2         51.0
# 3         26.0
# 4         47.0
#           ...
# 979106    44.0
# 979107    20.0
# 979108    44.0
# 979109    27.0
# 979110     3.0
# Name: EDAD, Length: 973395, dtype: float64

# %%
data["DEPARTAMENTO"].value_counts()
# Out:
# LIMA             403509
# AREQUIPA          46910
# CALLAO            41653
# PIURA             41522
# LA LIBERTAD       36096
# LIMA REGION       31970
# LAMBAYEQUE        31712
# ICA               31311
# ANCASH            29336
# JUNIN             26184
# LORETO            25231
# SAN MARTIN        24643
# CUSCO             24416
# CAJAMARCA         24311
# UCAYALI           19661
# HUANUCO           19539
# PUNO              18769
# AMAZONAS          18173
# MOQUEGUA          15563
# AYACUCHO          14803
# TACNA             14277
# MADRE DE DIOS      9345
# TUMBES             9248
# HUANCAVELICA       7752
# APURIMAC           6834
# PASCO              6343
# Name: DEPARTAMENTO, dtype: int64

# %%
data["DEPARTAMENTO"].value_counts().plot.pie();
